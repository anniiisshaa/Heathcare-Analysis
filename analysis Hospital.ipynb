# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/PC/OneDrive/Desktop/patients.csv")

# %%
df.head()
# Out:
#                                      Id   BIRTHDATE   DEATHDATE PREFIX  \
# 0  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19         NaN   Mrs.
# 1  6e5ae27c-8038-7988-e2c0-25a103f01bfa  1940-02-19         NaN    Mr.
# 2  8123d076-0886-9007-e956-d5864aa121a7  1958-06-04         NaN    Mr.
# 3  770518e4-6133-648e-60c9-071eb2f0e2ce  1928-12-25  2017-09-29    Mr.
# 4  f96addf5-81b9-0aab-7855-d208d3d352c5  1928-12-25  2014-02-23    Mr.
#
#        FIRST           LAST SUFFIX     MAIDEN MARITAL   RACE    ETHNICITY  \
# 0  Nikita578      Erdman779    NaN  Leannon79       M  white  nonhispanic
# 1    Zane918  Hodkiewicz467    NaN        NaN       M  white  nonhispanic
# 2   Quinn173   Marquardt819    NaN        NaN       M  white  nonhispanic
# 3    Abel832     Smitham825    NaN        NaN       M  white     hispanic
# 4   Edwin773     Labadie908    NaN        NaN       M  white     hispanic
#
#   GENDER                    BIRTHPLACE                       ADDRESS    CITY  \
# ...

# %%
df.tail()
# Out:
#                                        Id   BIRTHDATE DEATHDATE PREFIX  \
# 969  d684571e-a784-ef61-429e-06fa0d2b1637  1924-03-15       NaN    Mr.
# 970  13c6f26e-17b7-f534-04db-78a26b26018d  1940-10-31       NaN   Mrs.
# 971  521e998b-ff0e-767f-b0ee-2bdf1168d66c  1943-04-18       NaN    Mr.
# 972  b57e24a2-2e48-12f9-3293-c88745cfdc3f  1941-04-28       NaN   Mrs.
# 973  204f8028-72f8-d6f8-761f-79ebf9f02311  1923-02-14       NaN   Mrs.
#
#            FIRST          LAST SUFFIX       MAIDEN MARITAL   RACE  \
# 969      Chris95     Fisher429    NaN          NaN       S  white
# 970  Berneice173     Heaney114    NaN  Hermiston71       M  white
# 971     Jamal145  VonRueden376    NaN          NaN       M  white
# 972   Chrissy459     Rempel203    NaN      Beer512       M  asian
# 973   Melaine933      Hintz995    NaN  Baumbach677       M  white
#
#        ETHNICITY GENDER                     BIRTHPLACE  \
# 969  nonhispanic      M    Franklin  Massachusetts  US
# ...

# %%
df.tail()
# Out:
#                                        Id   BIRTHDATE DEATHDATE PREFIX  \
# 969  d684571e-a784-ef61-429e-06fa0d2b1637  1924-03-15       NaN    Mr.
# 970  13c6f26e-17b7-f534-04db-78a26b26018d  1940-10-31       NaN   Mrs.
# 971  521e998b-ff0e-767f-b0ee-2bdf1168d66c  1943-04-18       NaN    Mr.
# 972  b57e24a2-2e48-12f9-3293-c88745cfdc3f  1941-04-28       NaN   Mrs.
# 973  204f8028-72f8-d6f8-761f-79ebf9f02311  1923-02-14       NaN   Mrs.
#
#            FIRST          LAST SUFFIX       MAIDEN MARITAL   RACE  \
# 969      Chris95     Fisher429    NaN          NaN       S  white
# 970  Berneice173     Heaney114    NaN  Hermiston71       M  white
# 971     Jamal145  VonRueden376    NaN          NaN       M  white
# 972   Chrissy459     Rempel203    NaN      Beer512       M  asian
# 973   Melaine933      Hintz995    NaN  Baumbach677       M  white
#
#        ETHNICITY GENDER                     BIRTHPLACE  \
# 969  nonhispanic      M    Franklin  Massachusetts  US
# ...

# %%
df.tail()
# Out:
#                                        Id   BIRTHDATE DEATHDATE PREFIX  \
# 969  d684571e-a784-ef61-429e-06fa0d2b1637  1924-03-15       NaN    Mr.
# 970  13c6f26e-17b7-f534-04db-78a26b26018d  1940-10-31       NaN   Mrs.
# 971  521e998b-ff0e-767f-b0ee-2bdf1168d66c  1943-04-18       NaN    Mr.
# 972  b57e24a2-2e48-12f9-3293-c88745cfdc3f  1941-04-28       NaN   Mrs.
# 973  204f8028-72f8-d6f8-761f-79ebf9f02311  1923-02-14       NaN   Mrs.
#
#            FIRST          LAST SUFFIX       MAIDEN MARITAL   RACE  \
# 969      Chris95     Fisher429    NaN          NaN       S  white
# 970  Berneice173     Heaney114    NaN  Hermiston71       M  white
# 971     Jamal145  VonRueden376    NaN          NaN       M  white
# 972   Chrissy459     Rempel203    NaN      Beer512       M  asian
# 973   Melaine933      Hintz995    NaN  Baumbach677       M  white
#
#        ETHNICITY GENDER                     BIRTHPLACE  \
# 969  nonhispanic      M    Franklin  Massachusetts  US
# ...

# %%
df['AGE'] = pd.to_datetime('today').year - pd.to_datetime(df['BIRTHDATE']).dt.year

# %%
df
# Out:
#                                        Id   BIRTHDATE   DEATHDATE PREFIX  \
# 0    5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19         NaN   Mrs.
# 1    6e5ae27c-8038-7988-e2c0-25a103f01bfa  1940-02-19         NaN    Mr.
# 2    8123d076-0886-9007-e956-d5864aa121a7  1958-06-04         NaN    Mr.
# 3    770518e4-6133-648e-60c9-071eb2f0e2ce  1928-12-25  2017-09-29    Mr.
# 4    f96addf5-81b9-0aab-7855-d208d3d352c5  1928-12-25  2014-02-23    Mr.
# ..                                    ...         ...         ...    ...
# 969  d684571e-a784-ef61-429e-06fa0d2b1637  1924-03-15         NaN    Mr.
# 970  13c6f26e-17b7-f534-04db-78a26b26018d  1940-10-31         NaN   Mrs.
# 971  521e998b-ff0e-767f-b0ee-2bdf1168d66c  1943-04-18         NaN    Mr.
# 972  b57e24a2-2e48-12f9-3293-c88745cfdc3f  1941-04-28         NaN   Mrs.
# 973  204f8028-72f8-d6f8-761f-79ebf9f02311  1923-02-14         NaN   Mrs.
#
#            FIRST           LAST SUFFIX       MAIDEN MARITAL   RACE  ...  \
# ...

# %%
df['DEATH'] = df['DEATHDATE'].notna().astype(int)
df = df.drop(columns=['DEATHDATE'])

# %%
df
# Out:
#                                        Id   BIRTHDATE PREFIX        FIRST  \
# 0    5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19   Mrs.    Nikita578
# 1    6e5ae27c-8038-7988-e2c0-25a103f01bfa  1940-02-19    Mr.      Zane918
# 2    8123d076-0886-9007-e956-d5864aa121a7  1958-06-04    Mr.     Quinn173
# 3    770518e4-6133-648e-60c9-071eb2f0e2ce  1928-12-25    Mr.      Abel832
# 4    f96addf5-81b9-0aab-7855-d208d3d352c5  1928-12-25    Mr.     Edwin773
# ..                                    ...         ...    ...          ...
# 969  d684571e-a784-ef61-429e-06fa0d2b1637  1924-03-15    Mr.      Chris95
# 970  13c6f26e-17b7-f534-04db-78a26b26018d  1940-10-31   Mrs.  Berneice173
# 971  521e998b-ff0e-767f-b0ee-2bdf1168d66c  1943-04-18    Mr.     Jamal145
# 972  b57e24a2-2e48-12f9-3293-c88745cfdc3f  1941-04-28   Mrs.   Chrissy459
# 973  204f8028-72f8-d6f8-761f-79ebf9f02311  1923-02-14   Mrs.   Melaine933
#
#               LAST SUFFIX       MAIDEN MARITAL   RACE    ETHNICITY  ...  \
# ...

# %%
print(df.isnull().sum())
# Out:
# Id              0
# BIRTHDATE       0
# PREFIX          0
# FIRST           0
# LAST            0
# SUFFIX        953
# MAIDEN        588
# MARITAL         1
# RACE            0
# ETHNICITY       0
# GENDER          0
# BIRTHPLACE      0
# ADDRESS         0
# CITY            0
# STATE           0
# COUNTY          0
# ZIP           142
# LAT             0
# LON             0
# AGE             0
# DEATH           0
# dtype: int64

# %%
print(df.describe())
# Out:
#                ZIP         LAT         LON         AGE       DEATH
# count   832.000000  974.000000  974.000000  974.000000  974.000000
# mean   2152.421875   42.337359  -71.027524   73.243326    0.158111
# std      75.462146    0.047594    0.069375   20.483301    0.365032
# min    1801.000000   42.204921  -71.165648   34.000000    0.000000
# 25%    2121.000000   42.313366  -71.068002   55.250000    0.000000
# 50%    2135.000000   42.343794  -71.038397   75.000000    0.000000
# 75%    2163.000000   42.371594  -70.999202   92.000000    0.000000
# max    2472.000000   42.495464  -70.730824  103.000000    1.000000

# %%
print(df['MARITAL'].value_counts())
print(df['GENDER'].value_counts())
print(df['ETHNICITY'].value_counts())
# Out:
# MARITAL
# M    784
# S    189
# Name: count, dtype: int64
# GENDER
# M    494
# F    480
# Name: count, dtype: int64
# ETHNICITY
# nonhispanic    783
# hispanic       191
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.histplot(df['LAT'], kde=True)
plt.title('Distribution of LAT')
plt.show()
# Out:
# C:\Users\PC\anaconda3\conda22\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
print(df.duplicated().sum())
# Out:
# 0
