# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/PC/Downloads/Untitled spreadsheet - Query1.csv")

# %%
df
# Out:
#                                          Id          Full_Name     BIRTHDATE  \
# 0      d644e248-1127-2a63-a494-c570f926ba06     Margrett Kuhic  11/6/32 0:00
# 1      c83e8f1b-8f35-5855-0d38-6ea6509ec619  Ferdinand Goodwin  9/25/23 0:00
# 2      1712d26d-822d-1e3a-2267-0a9dba31d7c8   Kimberly Collier  6/30/29 0:00
# 3      1712d26d-822d-1e3a-2267-0a9dba31d7c8   Kimberly Collier  6/30/29 0:00
# 4      1712d26d-822d-1e3a-2267-0a9dba31d7c8   Kimberly Collier  6/30/29 0:00
# ...                                     ...                ...           ...
# 47696  3b66a28f-3d17-6260-d733-82b0951bb03d  Christopher Towne   7/5/31 0:00
# 47697  3b66a28f-3d17-6260-d733-82b0951bb03d  Christopher Towne   7/5/31 0:00
# 47698  6ae160e8-2a4a-b0d7-a3ed-3ce0da6c6843     James Emmerich  8/19/65 0:00
# 47699  44f7e37c-273c-cf1b-4812-a64f0cf052ca      Lorette Borer  5/15/33 0:00
# 47700  44f7e37c-273c-cf1b-4812-a64f0cf052ca      Lorette Borer  5/15/33 0:00
#
# ...

# %%
print(df.describe())
# Out:
#            BASE_COST  BASE_ENCOUNTER_COST  TOTAL_CLAIM_COST  PAYER_COVERAGE
# count   47701.000000         47701.000000      47701.000000    47701.000000
# mean     2212.064967           110.397706       8306.261995     3057.640727
# std      5572.978748            27.366963      18477.586417    10957.346681
# min         1.000000            85.550000          0.000000        0.000000
# 25%       431.000000            85.550000        385.730000        0.000000
# 50%       431.000000            85.550000       1139.820000       36.440000
# 75%       966.000000           142.580000      10627.570000      718.740000
# max    289531.000000           146.180000     641882.700000   247751.420000

# %%
print(df['MARITAL'].value_counts())
print(df['GENDER'].value_counts())
# Out:
# MARITAL
# M    38844
# S     8850
# Name: count, dtype: int64
# GENDER
# F    25633
# M    22068
# Name: count, dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Id                          0
# Full_Name                   0
# BIRTHDATE                   0
# MARITAL                     7
# GENDER                      0
# Patient_City                0
# Patient_State               0
# Patient_Country             0
# IF_Patient_Alive            0
# BASE_COST                   0
# Start_date_Encounter        0
# Stop_date_Encounter         0
# ENCOUNTER_CLASS             0
# BASE_ENCOUNTER_COST         0
# TOTAL_CLAIM_COST            0
# PAYER_COVERAGE              0
# Payer_Name                  0
# Payer_City              15102
# Payer_State             15102
# Organization_Name           0
# dtype: int64

# %%
# Count occurrences of "NO_INSURANCE" in the 'Payer_Name' column
no_insurance_count = df[df['Payer_Name'] == 'NO_INSURANCE'].shape[0]

# Print the count
print(no_insurance_count)
# Out:
# 15102

# %%
import seaborn as sns
sns.histplot(df['BASE_ENCOUNTER_COST'], kde=False)
plt.title('Distribution of BASE_ENCOUNTER_COST')
plt.show()
# Out:
# C:\Users\PC\anaconda3\conda22\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
print(df[['BASE_COST', 'TOTAL_CLAIM_COST']].describe())
# Out:
#            BASE_COST  TOTAL_CLAIM_COST
# count   47701.000000      47701.000000
# mean     2212.064967       8306.261995
# std      5572.978748      18477.586417
# min         1.000000          0.000000
# 25%       431.000000        385.730000
# 50%       431.000000       1139.820000
# 75%       966.000000      10627.570000
# max    289531.000000     641882.700000

# %%
print(df['Patient_City'].value_counts().head(10))
# Out:
# Patient_City
# Boston        28617
# Weymouth       2389
# Quincy         2314
# Hull           2151
# Chelsea        1829
# Cambridge      1659
# Somerville     1456
# Medford        1400
# Everett         947
# Revere          645
# Name: count, dtype: int64

# %%
print(df.groupby('Payer_Name')['PAYER_COVERAGE'].mean())
# Out:
# Payer_Name
# Aetna                         2.513198
# Anthem                        0.000000
# Blue Cross Blue Shield     7826.894643
# Cigna Health                  0.795178
# Dual Eligible              6229.033485
# Humana                        0.209365
# Medicaid                  19432.274317
# Medicare                   3615.884785
# NO_INSURANCE                  0.000000
# UnitedHealthcare              3.211926
# Name: PAYER_COVERAGE, dtype: float64
